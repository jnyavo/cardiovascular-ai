# %%
from data import ptbxl
import os

# %%
try:
  ptbxl.PTBXL()
except:
  os.chdir('../../')

# %%
dataset = ptbxl.PTBXL()
record = dataset.load_record(1)
record.draw_ecg(ptbxl.Lead.I)
record.draw_ecg(ptbxl.Lead.II)
